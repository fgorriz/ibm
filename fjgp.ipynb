# %% [markdown]
# # Ciencia de Datos: Fundamentos y Aplicaciones

# %% [markdown]
# ## Introducción
#
# Este cuaderno presenta los conceptos fundamentales de la ciencia de datos, incluyendo los lenguajes más utilizados, las bibliotecas y herramientas clave, y ejemplos básicos de operaciones aritméticas. Está diseñado para ser una guía introductoria con ejemplos prácticos.

# %% [markdown]
# ### Lenguajes de Ciencia de Datos
#
# 1. **Python**
# 2. **R**
# 3. **SQL**
# 4. **Julia**
# 5. **Scala**
# 6. **MATLAB**
# 7. **SAS**

# %% [markdown]
# ### Bibliotecas Populares en Ciencia de Datos
#
# - **pandas**: Manejo y análisis de datos estructurados.
# - **NumPy**: Computación numérica y manejo de matrices.
# - **Matplotlib**: Visualización básica de datos.
# - **Scikit-learn**: Algoritmos de Machine Learning.
# - **TensorFlow**: Deep Learning y redes neuronales.
# - **Seaborn**: Visualización de datos basada en Matplotlib.
# - **Statsmodels**: Modelos estadísticos.

# %% [markdown]
# ### Herramientas de Ciencia de Datos
#
# | Herramienta        | Descripción                               | Propósito                       |
# |--------------------|-------------------------------------------|----------------------------------|
# | **Jupyter Notebook**| Entorno interactivo para escribir código  | Desarrollo y visualización       |
# | **Apache Spark**    | Plataforma para procesamiento distribuido | Big Data y procesamiento rápido  |
# | **Tableau**         | Software de visualización de datos        | Visualización interactiva        |
# | **Power BI**        | Herramienta de análisis empresarial       | Visualización y análisis de datos|
# | **Git**             | Sistema de control de versiones           | Gestión y control de versiones   |

# %% [markdown]
# ### Ejemplos de Expresiones Aritméticas
#
# Las expresiones aritméticas son operaciones básicas que incluyen la suma, resta, multiplicación y división. A continuación, se presentan algunos ejemplos sencillos de estas operaciones en Python.

# %%
# Multiplicar y sumar números
a = 5
b = 3
multiplicacion = a * b
suma = a + b
print("Multiplicación:", multiplicacion)
print("Suma:", suma)
# Out:
# Multiplicación: 15
# Suma: 8

# %%
# Convertir minutos en horas
minutos = 150
horas = minutos / 60
print(f"{minutos} minutos son {horas} horas.")
# Out:
# 150 minutos son 2.5 horas.

# %%
# Lista de Objetivos
objetivos = ["Aprender conceptos básicos de ciencia de datos", 
             "Realizar operaciones aritméticas simples", 
             "Familiarizarse con bibliotecas clave", 
             "Entender herramientas y lenguajes principales"]

for i, objetivo in enumerate(objetivos, 1):
    print(f"{i}. {objetivo}")
# Out:
# 1. Aprender conceptos básicos de ciencia de datos
# 2. Realizar operaciones aritméticas simples
# 3. Familiarizarse con bibliotecas clave
# 4. Entender herramientas y lenguajes principales

# %% [markdown]
# ### Autor
#
# **Nombre del autor:** [F J Górriz Prieto]
